# %%
import pandas as pd
pd.set_option("display.max_rows", 180, "display.max_columns", None)

# %%
df = pd.read_table("hentschel_et_al_mozart_piano_data/mozart_data_joined.tsv")

# %%
df
# Out:
#        filename  notes_id  cadences_id  harmonies_id   mc   mn timesig   beat  \
# 0        K279-1       1.0          0.0             0    1    1     4/4      1
# 1        K279-1       2.0          0.0             0    1    1     4/4      1
# 2        K279-1       3.0          0.0             0    1    1     4/4      1
# 3        K279-1       0.0          0.0             0    1    1     4/4      1
# 4        K279-1       4.0          0.0             0    1    1     4/4  1.1/4
# 5        K279-1       5.0          0.0             0    1    1     4/4  1.1/2
# 6        K279-1       6.0          0.0             0    1    1     4/4  1.3/4
# 7        K279-1       7.0          0.0             0    1    1     4/4      2
# 8        K279-1       8.0          0.0             0    1    1     4/4  2.1/2
# 9        K279-1       9.0          0.0             0    1    1     4/4  2.3/4
# 10       K279-1      10.0          0.0             0    1    1     4/4      3
# ...

# %%
df
# Out:
#        filename  notes_id  cadences_id  harmonies_id   mc   mn timesig   beat  \
# 0        K279-1       1.0          0.0             0    1    1     4/4      1
# 1        K279-1       2.0          0.0             0    1    1     4/4      1
# 2        K279-1       3.0          0.0             0    1    1     4/4      1
# 3        K279-1       0.0          0.0             0    1    1     4/4      1
# 4        K279-1       4.0          0.0             0    1    1     4/4  1.1/4
# 5        K279-1       5.0          0.0             0    1    1     4/4  1.1/2
# 6        K279-1       6.0          0.0             0    1    1     4/4  1.3/4
# 7        K279-1       7.0          0.0             0    1    1     4/4      2
# 8        K279-1       8.0          0.0             0    1    1     4/4  2.1/2
# 9        K279-1       9.0          0.0             0    1    1     4/4  2.3/4
# 10       K279-1      10.0          0.0             0    1    1     4/4      3
# ...
